# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Import API key
from api_keys import weather_api_key
# !pip install citipy
# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 632

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it's being processed (with the city number and city name).

# %%
url = "http://api.openweathermap.org/data/2.5/weather?"
units = "metric"
query_url = f"{url}appid={weather_api_key}&units={units}&q="

city_df= pd.DataFrame({"City": cities})
city_df["Lat"]=""
city_df["Lng"] = ""
city_df["Max Temp"] = ""
city_df["Humidity"] = ""
city_df["Cloudiness"] = ""
city_df["Wind Speed"]=""
city_df["County"]=""
city_df["Date"]=""
city_df.head()
# Out:
#             City Lat Lng Max Temp Humidity Cloudiness Wind Speed County Date
# 0      mahebourg
# 1        rikitea
# 2          vaini
# 3    stepnogorsk
# 4  alto araguaia

# %%
count = 0
set = 1
for index , row in city_df.iterrows():
    query_url = f"{url}appid={weather_api_key}&units={units}&q="
    city = row['City']
   
    try:
        city_response= requests.get(query_url+city).json()
        print("Processing Record %s of Set %s | %s" % (count, set, city))
        city_df.loc[index, "Lat"]=city_response["coord"]["lat"]
        city_df.loc[index, "Lng"]=city_response["coord"]["lon"]
        city_df.loc[index, "Max Temp"]=city_response["main"]["temp_max"]
        city_df.loc[index, "Humidity"]=city_response["main"]['humidity']
        city_df.loc[index, "Cloudiness"]=city_response["clouds"]["all"]
        city_df.loc[index, "Wind Speed"]=city_response["wind"]["speed"]
        city_df.loc[index, "County"]=city_response["sys"]["country"]
        city_df.loc[index, "Date"]=city_response["dt"]
    except:
        print("City not found. Skipping ...")
    count=count+1
    if count==50:
        count=0
        set=set+1
print("Data Retrieval Complete")
# Out:
# Processing Record 0 of Set 1 | mahebourg
# Processing Record 1 of Set 1 | rikitea
# Processing Record 2 of Set 1 | vaini
# Processing Record 3 of Set 1 | stepnogorsk
# Processing Record 4 of Set 1 | alto araguaia
# Processing Record 5 of Set 1 | ponta do sol
# Processing Record 6 of Set 1 | belushya guba
# City not found. Skipping ...
# Processing Record 7 of Set 1 | tsihombe
# City not found. Skipping ...
# Processing Record 8 of Set 1 | hermanus
# Processing Record 9 of Set 1 | pawa
# Processing Record 10 of Set 1 | jamestown
# Processing Record 11 of Set 1 | burica
# City not found. Skipping ...
# Processing Record 12 of Set 1 | opuwo
# Processing Record 13 of Set 1 | leningradskiy
# Processing Record 14 of Set 1 | ipixuna
# Processing Record 15 of Set 1 | busselton
# Processing Record 16 of Set 1 | muravlenko
# Processing Record 17 of Set 1 | kunnamkulam
# Processing Record 18 of Set 1 | berlevag
# Processing Record 19 of Set 1 | sidi ali
# Processing Record 20 of Set 1 | tsogni
# ...

# %%
city_df.head()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [17], in <cell line: 1>()
# ----> 1 city_df.head()
#
# AttributeError: 'NoneType' object has no attribute 'head'

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
city_df.to_csv("cityweather_Output.csv")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [15], in <cell line: 1>()
# ----> 1 city_df.to_csv("cityweather_Output.csv")
#
# AttributeError: 'NoneType' object has no attribute 'to_csv'

# %%
city_df.head(20)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [14], in <cell line: 1>()
# ----> 1 city_df.head(20)
#
# AttributeError: 'NoneType' object has no attribute 'head'

# %%
city_df.dtypes
# Out:
# City          object
# Lat           object
# Lng           object
# Max Temp      object
# Humidity      object
# Cloudiness    object
# Wind Speed    object
# County        object
# Date          object
# dtype: object

# %%
city_newdf=city_df.dropna()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [13], in <cell line: 1>()
# ----> 1 city_newdf=city_df.dropna()
#
# AttributeError: 'NoneType' object has no attribute 'dropna'

# %%
city_df= city_df.dropna(inplace=True)
city_df
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [10], in <cell line: 1>()
# ----> 1 city_df= city_df.dropna(inplace=True)
#       2 city_df
#
# AttributeError: 'NoneType' object has no attribute 'dropna'

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [9], in <cell line: 1>()
# ----> 1 city_df.info()
#
# AttributeError: 'NoneType' object has no attribute 'info'

# %%
pd.to_numeric(city_df["Humidity"])
city_df.info()

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%.
# ----
# Skip this step if there are no cities that have humidity > 100%.

# %%
#  Get the indices of cities that have humidity over 100%.

high_humidity_df=city_df.loc[city_df["Humidity"] > 100]
high_humidity_df

# %%
# Make a new DataFrame equal to the city data to drop all humidity outliers by index.
# Passing "inplace=False" will make a copy of the city_data DataFrame, which we call "clean_city_data".

# %% [markdown]
# ## Plotting the Data
# * Use proper labelling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %% [markdown]
# ## Linear Regression

# %% [markdown]
# ###  Max Temp vs. Latitude Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %% [markdown]
# ### Humidity (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %% [markdown]
# ### Cloudiness (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %% [markdown]
# ### Wind Speed (m/s) vs. Latitude Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression
